# %%
import json

def guardar_json(datos, filename):
    '''creacion de funcion para guardar 
    diccionario de conocimiento en formato json'''
    archivo=open(filename,"w")
    json.dump(datos,archivo,indent=4)

biblioteca = {
            "intents": [
                {
                "tag": "harassment",
                "patterns": [
                    "I feel harassed",
                    "Someone is harassing me",
                    "I'm being bullied",
                    "I feel uncomfortable with someone's behavior",
                    "This person is bothering me",
                    "I don't know how to stop the harassment",
                    "Help, I'm being harassed",
                    "I'm afraid someone is harassing me",
                    "I feel unsafe because of harassment",
                    "This person won't leave me alone",
                    "I feel threatened by someone's behavior",
                    "They keep making inappropriate comments"
                ],
                "responses": [
                    "I'm really sorry to hear that you're going through this. It's important to talk to someone you trust, such as a friend, family member, or professional.",
                    "You don't deserve to be harassed. Please consider reaching out to a support service or a professional who can help.",
                    "It might be helpful to talk to someone who can provide guidance, such as a counselor or a trusted individual. You don't have to go through this alone.",
                    "Harassment is never okay. Please consider reporting it to authorities or reaching out to a support group.",
                    "It's important to set boundaries. If you're able, remove yourself from the situation and reach out for support.",
                    "Remember, you're not alone. There are resources available that can assist you."
                ]
                },
                {
                "tag": "depression",
                "patterns": [
                    "I feel depressed",
                    "I feel hopeless",
                    "I don't know what to do, I feel so down",
                    "I'm not interested in anything anymore",
                    "I feel empty inside",
                    "Everything feels pointless",
                    "I just want to be left alone",
                    "I can't find the energy to do anything",
                    "I feel like I'm in a dark place",
                    "Life feels overwhelming"
                ],
                "responses": [
                    "I'm really sorry you're feeling this way. It's important to talk to a professional who can help you manage these emotions.",
                    "You are not alone in this. Please reach out to someone you trust, whether it's a friend, family member, or counselor.",
                    "It's okay to feel this way sometimes. Please consider speaking to a therapist or a mental health professional for support.",
                    "Take small steps. Reach out for help, and remember that things can get better with the right support.",
                    "It may be helpful to talk about how you're feeling with someone who can provide support. You're not alone."
                ]
                },
                {
                "tag": "sexism",
                "patterns": [
                    "I feel like I'm being treated unfairly because of my gender",
                    "Men are always put first",
                    "Why are women always dismissed?",
                    "I feel like men think they are superior",
                    "There's a lot of sexism around me",
                    "I feel like I'm not taken seriously because I'm a woman",
                    "Why is society so biased towards men?",
                    "Why do people think men are always right?",
                    "I don't like the way men are treated better than women",
                    "Why do I feel like I'm being controlled because I'm a woman?"
                ],
                "responses": [
                    "Gender equality is very important. It's essential to have conversations and challenge these unfair beliefs.",
                    "No one should feel inferior because of their gender. It's important to raise awareness about sexism and work towards a more inclusive society.",
                    "It's okay to stand up against unfair treatment. You deserve to be respected and treated equally.",
                    "Gender discrimination is a real issue, and you are not alone in your feelings. Keep advocating for equality.",
                    "Everyone deserves respect, regardless of gender. Don't be afraid to speak out against discrimination."
                ]
                },
                {
                "tag": "xenophobia",
                "patterns": [
                    "I feel like I'm treated differently because of my nationality",
                    "Why do people hate others for being from a different country?",
                    "I feel unwelcome because of where I come from",
                    "Why does everyone treat me differently because of my accent?",
                    "I feel discriminated against because of my background",
                    "Why do people judge me for my nationality?",
                    "I don't understand why people are so racist towards immigrants",
                    "I'm tired of people looking down on me for being foreign",
                    "I feel excluded because I'm not from here",
                    "I face so much xenophobia where I live"
                ],
                "responses": [
                    "No one should be treated unfairly because of where they come from. Xenophobia is a serious issue that needs to be addressed.",
                    "You deserve to feel welcomed and respected, no matter your background. Please consider finding a support group that understands your experiences.",
                    "Everyone deserves to be treated with kindness and dignity, regardless of nationality. It's important to stand up against xenophobia.",
                    "Immigrants enrich society, and no one should feel excluded because of their nationality. You have the right to be here and feel safe.",
                    "It's important to raise awareness and continue fighting against xenophobia. You are not alone."
                ]
                },
                {
                "tag": "racism",
                "patterns": [
                    "I feel like people are racist towards me",
                    "Why do people hate others because of their skin color?",
                    "I feel discriminated against because of my race",
                    "Why do people treat me differently because of my ethnicity?",
                    "I feel like I can't escape racism",
                    "I'm tired of facing racism every day",
                    "Why do people think they are superior because of their race?",
                    "I feel invisible because of my race",
                    "I'm treated unfairly because of my skin color",
                    "Racism is a problem everywhere"
                ],
                "responses": [
                    "Racism is a terrible issue, and you don't deserve to face it. It's important to stand up against it and raise awareness.",
                    "You have every right to be treated equally and with respect, regardless of your race. Please reach out to those who can offer support.",
                    "Racism hurts, and it's important to speak out against it. Together, we can work towards a more inclusive and just world.",
                    "You are not alone in this. There are many people and organizations that are actively working to combat racism and support victims.",
                    "Keep advocating for equality, and don't let others' ignorance define you. You deserve to be treated with dignity."
                ]
                },

                {"tag":"noanswer",
                 "patterns":[""],
                 "responses":["no response was detected"]                    
                }
            ]
}


# Guardado de diccionario de conocimiento en formato json.
guardar_json(biblioteca, 'intents.json')
biblioteca
# Out:
# {'intents': [{'tag': 'harassment',
#    'patterns': ['I feel harassed',
#     'Someone is harassing me',
#     "I'm being bullied",
#     "I feel uncomfortable with someone's behavior",
#     'This person is bothering me',
#     "I don't know how to stop the harassment",
#     "Help, I'm being harassed",
#     "I'm afraid someone is harassing me",
#     'I feel unsafe because of harassment',
#     "This person won't leave me alone",
#     "I feel threatened by someone's behavior",
#     'They keep making inappropriate comments'],
#    'responses': ["I'm really sorry to hear that you're going through this. It's important to talk to someone you trust, such as a friend, family member, or professional.",
#     "You don't deserve to be harassed. Please consider reaching out to a support service or a professional who can help.",
#     "It might be helpful to talk to someone who can provide guidance, such as a counselor or a trusted individual. You don't have to go through this alone.",
# ...
